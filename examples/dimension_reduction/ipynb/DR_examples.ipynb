# %%
#!/usr/bin/env python

# %%
import wuml 
import numpy as np
# Out:
# 2021-10-27 10:39:25.381222: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
X = np.vstack((np.random.randn(10,4), np.random.randn(10,4) + 10))
print('Dimension Before', X.shape)
# Out:
# Dimension Before (20, 4)

# %% [markdown]
# Run a single method

# %%
Xᵈ = wuml.dimension_reduction(X, 2, method='PCA', show_plot=True)
print('Dimension After', Xᵈ.shape)
# Out:
# Dimension After (20, 2)

# %% [markdown]
# Run a all methods

# %%
wuml.show_multiple_dimension_reduction_results(X, 2, learning_rate=14, n_neighbors=10, gamma=0.05)
# Out:
# Graph is not fully connected, spectral embedding may not work as expected.

# %%
#!/usr/bin/env python

# %%
import wuml 
import numpy as np
# Out:
# 2021-11-05 10:20:33.790088: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
X1 = np.vstack((np.random.randn(10,1), 0.01*np.random.randn(10,1) + 10))
X2 = np.vstack((0.01*np.random.randn(10,1), np.random.randn(10,1) + 10))
X3 = 0.01*np.random.randn(20,2)
X = np.hstack((X1, X2, X3))
X = wuml.ensure_DataFrame(X, columns=['A','B','C','D'])
print('Dimension Before', X.shape)
# Out:
# Dimension Before (20, 4)

# %% [markdown]
# Run a single method

# %%
Xᵈ = wuml.dimension_reduction(X, 2, method='PCA', show_plot=True)
print('Dimension After', Xᵈ.shape)
print('Eigen Vectors')
print(Xᵈ.eig_vectors)
print('\nNormalized Eigen Values')
print(Xᵈ.normalized_eigs)
print('\nAcccumulative Eigen Values')
print(Xᵈ.cumulative_eigs)
# Out:
# Dimension After (20, 2)
# Eigen Vectors
#          λ1        λ2        λ3        λ4
# A -0.683088 -0.730336 -0.000413  0.000379
# B  0.730324 -0.683072 -0.006319  0.000619
# C -0.001669  0.002243 -0.343389  0.939189
# D -0.004003  0.004097 -0.939172 -0.343399
#
# Normalized Eigen Values
# [0.9906 0.0094 0.     0.    ]
#
# Acccumulative Eigen Values
# [0.9098 0.9982 0.9993 1.    ]

# %% [markdown]
# Run a all methods

# %%
wuml.show_multiple_dimension_reduction_results(X, learning_rate=14, n_neighbors=10, gamma=0.01)
# Out:
# Graph is not fully connected, spectral embedding may not work as expected.

# %%
#!/usr/bin/env python
import os
import sys
if os.path.exists('/home/chieh/code/wuML'):
	sys.path.insert(0,'/home/chieh/code/wuML')
import wuml

# %%
data = wuml.wData('../../data/missin_example.csv', first_row_is_label=True)
wuml.missing_data_stats(data)
# Out:
# Warning: 40 entries are missing.
# <style type="text/css">
# #T_bff9d th {
#   text-align: center;
# }
# #T_bff9d td {
#   text-align: center;
# }
# </style>
# <table id="T_bff9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bff9d_level0_col0" class="col_heading level0 col0" >missing %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bff9d_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_bff9d_row0_col0" class="data row0 col0" >80.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bff9d_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_bff9d_row1_col0" class="data row1 col0" >6.666667</td>
#     </tr>
#     <tr>
#       <th id="T_bff9d_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_bff9d_row2_col0" class="data row2 col0" >46.666667</td>
#     </tr>
#     <tr>
#       <th id="T_bff9d_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_bff9d_row3_col0" class="data row3 col0" >46.666667</td>
#     </tr>
#     <tr>
#       <th id="T_bff9d_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_bff9d_row4_col0" class="data row4 col0" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bff9d_level0_row5" class="row_heading level0 row5" >F</th>
#       <td id="T_bff9d_row5_col0" class="data row5 col0" >66.666667</td>
#     </tr>
#   </tbody>
# </table>
# array([80.    ,  6.6667, 46.6667, 46.6667, 20.    , 66.6667])
